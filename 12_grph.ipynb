# %% [markdown]
# <a href="https://colab.research.google.com/github/nitrozyna/Rosalind/blob/master/12_grph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem description:
# [Overlap Graphs](http://rosalind.info/problems/grph/
# )

# %% [markdown]
# A graph whose nodes have all been labeled can be represented by an **adjacency list**, in which each row of the list contains the two node labels corresponding to a unique edge.
#
# A **directed graph** (or digraph) is a graph containing **directed edges**, each of which has an orientation. That is, a directed edge is represented by an arrow instead of a line segment; the starting and ending nodes of an edge form its **tail** and **head**, respectively. The directed edge with tail v and head w is represented by (v,w) (but not by (w,v)). A **directed loop** is a directed edge of the form (v,v).
#
# For a collection of strings and a positive integer k, the **overlap graph** for the strings is a directed graph Ok in which each string is represented by a node, and string s is connected to string t with a directed edge when there is a length k **suffix** of s that matches a length k **prefix** of t, as long as s≠t; we demand s≠t to prevent directed loops in the overlap graph (although directed cycles may be present).
# ---
#
# ### Given: A collection of DNA strings in FASTA format having total length at most 10 kbp.
#
# ### Return:  The adjacency list corresponding to O3. You may return edges in any order.
#
# Sample Dataset
#
# >Rosalind_0498
# AAATAAA
# >Rosalind_2391
# AAATTTT
# >Rosalind_2323
# TTTTCCC
# >Rosalind_0442
# AAATCCC
# >Rosalind_5013
# GGGTGGG
#
# Sample Output
#
# Rosalind_0498 Rosalind_2391
# Rosalind_0498 Rosalind_0442
# Rosalind_2391 Rosalind_2323

# %%
#@title Importing some modules to make a connection between Colab and Drive to download the current dataset
# !pip install PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
#@title Loading test dataset
fileID = "1QAXg4Gv3NLAjd9fktPol1Lm9awSRD_Qg" #@param {type:"string"}
downloaded = drive.CreateFile({'id':fileID})
downloaded.GetContentFile('rosalind_grph.txt')  # replace the file name with your file

# %%
#@title Manipulating the file to give a dictionary of read names and DNA strings
with open('rosalind_grph.txt','r') as f:
    reads = {}
    for line in f:
        line = line.strip()
        if line.startswith(">"):
            reads[line[1:]] = ""
            mem_line = line[1:]
        else:
            reads[mem_line] += line
    overlapGraph(list(reads.values()))

# %%
#@title Making a dictionary of suffix-prefix pairs
def overlapGraph(reads):
    suffix_dict = {}
    for read in reads:
        if read in suffix_dict:
            pass
        else:
            suffix_dict[read] = []
    for read in reads:
        for key in suffix_dict.keys():
            if read[:3] == key[-3:]:
                suffix_dict[key].append(read)
    return suffix_dict
sp_dict = overlapGraph(list(reads.values()))

# %%
#@title Pretty printing all the read pairs
for k,v in sp_dict.items():
    if v != []:
        for name,dna in reads.items():
            if k == dna:
                prefix = name   
                for item in v:
                    for kk,vv in reads.items():
                        if item == vv:
                            suffix = kk
                            print(prefix,suffix)
                            break
# Out:
# Rosalind_7516 Rosalind_1005
# Rosalind_7516 Rosalind_5466
# Rosalind_3433 Rosalind_1619
# Rosalind_6325 Rosalind_8840
# Rosalind_6325 Rosalind_8550
# Rosalind_3942 Rosalind_1619
# Rosalind_8007 Rosalind_5933
# Rosalind_8007 Rosalind_8910
# Rosalind_8007 Rosalind_6014
# Rosalind_8007 Rosalind_5835
# Rosalind_8007 Rosalind_9494
# Rosalind_3560 Rosalind_6885
# Rosalind_3560 Rosalind_1557
# Rosalind_3560 Rosalind_6880
# Rosalind_5933 Rosalind_4959
# Rosalind_5933 Rosalind_3306
# Rosalind_5933 Rosalind_9094
# Rosalind_5933 Rosalind_7549
# Rosalind_2697 Rosalind_5933
# Rosalind_2697 Rosalind_8910
# Rosalind_2697 Rosalind_6014
# Rosalind_2697 Rosalind_5835
# Rosalind_2697 Rosalind_9494
# Rosalind_5822 Rosalind_6499
# Rosalind_5822 Rosalind_6263
# Rosalind_5822 Rosalind_6400
# Rosalind_3967 Rosalind_8922
# Rosalind_4959 Rosalind_9511
# Rosalind_4959 Rosalind_3351
# Rosalind_9511 Rosalind_8840
# Rosalind_9511 Rosalind_8550
# Rosalind_2021 Rosalind_8760
# Rosalind_2021 Rosalind_6256
# Rosalind_1557 Rosalind_6325
# Rosalind_1557 Rosalind_2010
# Rosalind_1557 Rosalind_3795
# Rosalind_6126 Rosalind_8922
# Rosalind_1312 Rosalind_6499
# Rosalind_1312 Rosalind_6263
# Rosalind_1312 Rosalind_6400
# Rosalind_3306 Rosalind_2388
# Rosalind_3306 Rosalind_9470
# Rosalind_1599 Rosalind_5822
# Rosalind_1599 Rosalind_6944
# Rosalind_7047 Rosalind_8007
# Rosalind_7047 Rosalind_2697
# Rosalind_7757 Rosalind_1005
# Rosalind_7757 Rosalind_5466
# Rosalind_8922 Rosalind_1272
# Rosalind_8910 Rosalind_2241
# Rosalind_8910 Rosalind_3376
# Rosalind_8910 Rosalind_4663
# Rosalind_9158 Rosalind_9585
# Rosalind_1744 Rosalind_1312
# Rosalind_6014 Rosalind_1822
# Rosalind_2241 Rosalind_3560
# Rosalind_2281 Rosalind_9585
# Rosalind_6880 Rosalind_6325
# Rosalind_6880 Rosalind_2010
# Rosalind_6880 Rosalind_3795
# Rosalind_8840 Rosalind_5177
# Rosalind_8760 Rosalind_2064
# Rosalind_2599 Rosalind_0752
# Rosalind_3376 Rosalind_6793
# Rosalind_1272 Rosalind_1599
# Rosalind_0728 Rosalind_5177
# Rosalind_9585 Rosalind_3433
# Rosalind_9585 Rosalind_7757
# Rosalind_8368 Rosalind_2632
# Rosalind_2388 Rosalind_9585
# Rosalind_3711 Rosalind_9585
# Rosalind_1005 Rosalind_6126
# Rosalind_1005 Rosalind_2281
# Rosalind_3568 Rosalind_2599
# Rosalind_3568 Rosalind_2603
# Rosalind_3568 Rosalind_8133
# Rosalind_6060 Rosalind_8798
# Rosalind_6060 Rosalind_8368
# Rosalind_0222 Rosalind_7047
# Rosalind_0222 Rosalind_5754
# Rosalind_6255 Rosalind_8922
# Rosalind_9013 Rosalind_3433
# Rosalind_9013 Rosalind_7757
# Rosalind_2603 Rosalind_8760
# Rosalind_2603 Rosalind_6256
# Rosalind_8219 Rosalind_4302
# Rosalind_9053 Rosalind_2241
# Rosalind_9053 Rosalind_3376
# Rosalind_9053 Rosalind_4663
# Rosalind_0871 Rosalind_9585
# Rosalind_7141 Rosalind_2021
# Rosalind_7141 Rosalind_2876
# Rosalind_7141 Rosalind_8767
# Rosalind_7141 Rosalind_0919
# Rosalind_2064 Rosalind_5933
# Rosalind_2064 Rosalind_8910
# Rosalind_2064 Rosalind_6014
# Rosalind_2064 Rosalind_5835
# Rosalind_2064 Rosalind_9494
# Rosalind_2371 Rosalind_2064
# Rosalind_9750 Rosalind_2599
# Rosalind_9750 Rosalind_2603
# Rosalind_9750 Rosalind_8133
# Rosalind_3625 Rosalind_1312
# Rosalind_8767 Rosalind_6060
# Rosalind_8767 Rosalind_3716
# Rosalind_1822 Rosalind_6082
# Rosalind_0634 Rosalind_1312
# Rosalind_9470 Rosalind_2241
# Rosalind_9470 Rosalind_3376
# Rosalind_9470 Rosalind_4663
# Rosalind_9600 Rosalind_8840
# Rosalind_9600 Rosalind_8550
# Rosalind_6944 Rosalind_9158
# Rosalind_6944 Rosalind_5193
# Rosalind_6256 Rosalind_0595
# Rosalind_4302 Rosalind_1312
# Rosalind_5466 Rosalind_4959
# Rosalind_5466 Rosalind_3306
# Rosalind_5466 Rosalind_9094
# Rosalind_5466 Rosalind_7549
# Rosalind_0752 Rosalind_4302
# Rosalind_8033 Rosalind_8637
# Rosalind_8033 Rosalind_9600
# Rosalind_5835 Rosalind_0595
# Rosalind_8133 Rosalind_2241
# Rosalind_8133 Rosalind_3376
# Rosalind_8133 Rosalind_4663
# Rosalind_3795 Rosalind_3560
# Rosalind_9094 Rosalind_5822
# Rosalind_9094 Rosalind_6944
# Rosalind_9494 Rosalind_9511
# Rosalind_9494 Rosalind_3351
# Rosalind_3716 Rosalind_8798
# Rosalind_3716 Rosalind_8368
# Rosalind_6400 Rosalind_6082
# Rosalind_0595 Rosalind_9053
# Rosalind_0595 Rosalind_0634
# Rosalind_8550 Rosalind_5654
# Rosalind_0919 Rosalind_6499
# Rosalind_0919 Rosalind_6263
# Rosalind_0919 Rosalind_6400
# Rosalind_0352 Rosalind_3942
# Rosalind_0352 Rosalind_1744
# Rosalind_0352 Rosalind_9013
# Rosalind_5754 Rosalind_2599
# Rosalind_5754 Rosalind_2603
# Rosalind_5754 Rosalind_8133
# Rosalind_0365 Rosalind_6885
# Rosalind_0365 Rosalind_1557
# Rosalind_0365 Rosalind_6880
# Rosalind_5193 Rosalind_2064
